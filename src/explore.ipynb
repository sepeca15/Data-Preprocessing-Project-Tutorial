# %% [markdown]
# # Explore here
#
# It's recommended to use this notebook for exploration purposes.
#
# For example:
#
# 1. You could import the CSV generated by python into your notebook and explore it.
# 2. You could connect to your database using `pandas.read_sql` from this notebook and explore it.

# %%
# Example reading the SQL database from here

from utils import db_connect
import pandas as pd
engine = db_connect()

dataframe = pd.read_sql("Select * from books;", engine)
print(dataframe.describe())

# %%
# Example importing the CSV here

# dataframe = pd.read_csv('../path/to/file.csv')
# dataframe.describe()

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt  
# !pip install seaborn
import seaborn as sns
import seaborn as sb
# !pip install plotly
import plotly.graph_objects as go
# !pip install folium
import folium
from folium.plugins import MarkerCluster
from folium import plugins
from folium.plugins import FastMarkerCluster
from folium.plugins import HeatMap
# Out:
# Requirement already satisfied: seaborn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.8.1)
# Requirement already satisfied: numpy>=1.15 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.23.0)
# Requirement already satisfied: pandas>=0.23 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: matplotlib>=2.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.33.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (9.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# Collecting folium
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.9 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from folium) (2.27.1)
# Requirement already satisfied: numpy in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from folium) (1.23.0)
# Collecting branca>=0.3.0
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->folium) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests->folium) (2022.5.18.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.5.0 folium-0.12.1.post1
# WARNING: There was an error checking the latest version of pip.

# %%
url = 'https://raw.githubusercontent.com/4GeeksAcademy/data-preprocessing-project-tutorial/main/AB_NYC_2019.csv'
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %%
df.sample(5)
# Out:
#              id                                 name    host_id host_name  \
# 3379    2025779    Charming East Village One Bedroom     212572     Joyce
# 47289  35676738             Comfortable Private Room  264362310      Lens
# 46972  35518708                EMPIRE STATE BUILDING  241985816    Carlos
# 12327   9517131  Cleanly Kept Manhattan Bedroom FiDi   42807409      Sami
# 8720    6693403        PERFECT FOR A SMALL GET AWAY.   10717539     Eddie
#
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 3379            Manhattan        East Village  40.72977  -73.98713
# 47289            Brooklyn      Sheepshead Bay  40.60724  -73.95219
# 46972              Queens             Astoria  40.76822  -73.90783
# 12327           Manhattan  Financial District  40.71002  -74.00723
# 8720             Brooklyn            Flatbush  40.63485  -73.96208
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 3379   Entire home/apt    175               4                  0         NaN
# 47289     Private room     25               1                  0         NaN
# 46972     Private room     85               1                  1  2019-06-17
# 12327     Private room     98               3                  0         NaN
# 8720   Entire home/apt    175               1                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 3379                 NaN                               1                 0
# 47289                NaN                               1               178
# 46972                1.0                               3                60
# 12327                NaN                               1                 0
# 8720                 NaN                               1                 0

# %%
df.shape()

# %%
df.hist()
plt.show()

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
Long=-73.80
Lat=40.80
locations = list(zip(df.latitude, df.longitude))

map1 = folium.Map(location=[Lat,Long], zoom_start=9)
FastMarkerCluster(data=locations).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acddd29443e384790339c810a192fb93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acddd29443e384790339c810a192fb93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_acddd29443e384790339c810a192fb93 = L.map(
#                 &quot;map_acddd29443e384790339c810a192fb93&quot;,
#                 {
#                     center: [40.8, -73.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0819e5b8032a5aface8fb3e0b829e84e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_acddd29443e384790339c810a192fb93);
#
#
#             var fast_marker_cluster_f9875cd1cb7d70388aa84acd7743868c = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[40.64749, -73.97237], [40.75362, -73.98377], [40.80902, -73.9419], [40.68514, -73.95976], [40.79851, -73.94399], [40.74767, -73.975], [40.68688, -73.95596], [40.76489, -73.98493], [40.80178, -73.96723], [40.71344, -73.99037], [40.80316, -73.96545], [40.76076, -73.98867], [40.66829, -73.98779], [40.79826, -73.96113], [40.7353, -74.00525], [40.70837, -73.95352], [40.69169, -73.97185], [40.74192, -73.99501], [40.67592, -73.94694], [40.79685, -73.94872], [40.71842, -73.95718], [40.68069, -73.97706], [40.67989, -73.97798], [40.68001, -73.97865], [40.68371, -73.94028], [40.65599, -73.97519], [40.86754, -73.92639], [40.76715, -73.98533], [40.86482, -73.92106], [40.7292, -73.98542], [40.82245, -73.95104], [40.81305, -73.95466], [40.72219, -73.93762], [40.8213, -73.95318], [40.6831, -73.95473], [40.66869, -73.9878], [40.68876, -73.94312], [40.70186, -73.92745], [40.63702, -73.96327], [40.71401, -73.98917], [40.7229, -73.98199], [40.66278, -73.97966], [40.69673, -73.97584], [40.79009, -73.97927], [40.81175, -73.94478], [40.65944, -73.96238], [40.74771, -73.9474], [40.68111, -73.95591], [40.68554, -73.9409], [40.69142, -73.97376], [40.68043, -73.93934], [40.78635, -73.97008], [40.7042, -73.9356], [40.73506, -73.95392], [40.73961, -73.98074], [40.70881, -73.9593], [40.72004, -73.99104], [40.75531, -73.99293], [40.72401, -73.93788], [40.7221, -73.99775], [40.71185, -73.96204], [40.74623, -73.9953], [40.77065, -73.95269], [40.67811, -73.96428], [40.69, -73.96788], [40.75979, -73.99119], [40.67343, -73.98338], [40.72649, -73.97904], [40.70933, -73.96792], [40.72298, -73.98474], [40.80164, -73.93922], [40.72162, -73.98008], [40.76342, -73.98865], [40.83139, -73.94095], [40.68346, -73.96374], [40.72828, -73.98801], [40.76865, -73.95058], [40.75038, -73.90334], [40.6932, -73.97267], [40.74138, -74.00197], [40.71154, -73.96112], [40.82915, -73.95136], [40.71851, -73.98892], [40.65401, -73.96323], [40.7114, -73.98794], [40.69723, -73.99268], [40.71833, -73.95748], [40.72334, -73.9844], [40.72912, -73.98057], [40.71156, -73.96218], [40.70032, -73.9383], [40.68233, -73.97261], [40.68634, -73.966], [40.68035, -73.97162], [40.70984, -73.95775], [40.70093, -73.92609], [40.79764, -73.96177], [40.82803, -73.94731], [40.74008, -74.00271], [40.68413, -73.92357], [40.82279, -73.95139], [40.67967, -74.00154], [40.83927, -73.94281], [40.73096, -74.00319], [40.71332, -73.94177], [40.66941, -73.98109], [40.68373, -73.92377], [40.71459, -73.94844], [40.8092, -73.94421], [40.68157, -73.98989], [40.75527, -73.99291], [40.68698, -73.96572], [40.7288, -73.98192], [40.66853, -73.98912], [40.7254, -73.98157], [40.74294, -73.98009], [40.71942, -73.95748], [40.77823, -73.97637], [40.72555, -73.97965], [40.66831, -73.98604], [40.82754, -73.94919], [40.66499, -73.97925], [40.77842, -73.97556], [40.72245, -73.98527], [40.65593, -73.96053], [40.71923, -73.96468], [40.778, -73.94822], [40.85879, -73.93128], [40.68332, -73.9547], [40.81618, -73.94894], [40.68414, -73.96351], [40.72392, -73.99143], [40.73494, -73.9503], [40.71341, -73.98856], [40.76754, -73.98399], [40.73442, -74.00303], [40.63188, -73.93248], [40.6873, -73.9634], [40.68296, -73.93662], [40.6863, -73.96765], [40.73409, -73.95348], [40.71561, -73.94835], [40.6857, -73.99183], [40.74028, -73.83168], [40.68281, -73.93524], [40.71596, -73.93938], [40.71492, -73.95935], [40.72354, -73.98295], [40.71165, -73.96

# %%
df.neighbourhood_group.nunique()
# Out:
# 5

# %%
df.neighbourhood_group.value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df.longitude,y=df.latitude,hue=df.neighbourhood_group)
plt.show()

# %%
df['room_type'].value_counts().plot(kind='bar',color=['r','b','y'])
plt.show()

# %%
apt = df[df['room_type']=='Entire home/apt']
df_apt_group = apt.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name='apartment').sort_values(by=['apartment'],ascending=False)
df_apt_group.head(10)
# Out:
#          host_id     host_name       neighbourhood neighbourhood_group  \
# 20211  219517861  Sonder (NYC)  Financial District           Manhattan
# 6449     7503643          Vida          Greenpoint            Brooklyn
# 8430    12243051        Sonder  Financial District           Manhattan
# 20214  219517861  Sonder (NYC)         Murray Hill           Manhattan
# 19900  205031545    Red Awning             Midtown           Manhattan
# 17832  120762452       Stanley         Murray Hill           Manhattan
# 12273   30283594          Kara      Hell's Kitchen           Manhattan
# 17451  107434423    Blueground             Chelsea           Manhattan
# 12275   30283594          Kara             Midtown           Manhattan
# 17628  113805886        Yaacov     Upper East Side           Manhattan
#
#        apartment
# 20211        210
# 6449          52
# 8430          51
# 20214         50
# 19900         49
# 17832         49
# 12273         41
# 17451         37
# 12275         33
# 17628         33

# %%
df['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
figsize=(12,8)
sns.boxenplot(x='price',data=df)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
df_price = df[df['price'] > 0]

# %%
df_price.reset_index(inplace=True)

# %%
df_price
# Out:
#        index        id                                               name  \
# 0          0      2539                 Clean & quiet apt home by the park
# 1          1      2595                              Skylit Midtown Castle
# 2          2      3647                THE VILLAGE OF HARLEM....NEW YORK !
# 3          3      3831                    Cozy Entire Floor of Brownstone
# 4          4      5022   Entire Apt: Spacious Studio/Loft by central park
# ...      ...       ...                                                ...
# 48879  48890  36484665    Charming one bedroom - newly renovated rowhouse
# 48880  48891  36485057      Affordable room in Bushwick/East Williamsburg
# 48881  48892  36485431            Sunny Studio at Historical Neighborhood
# 48882  48893  36485609               43rd St. Time Square-cozy single bed
# 48883  48894  36487245  Trendy duplex in the very heart of Hell's Kitchen
#
#         host_id      host_name neighbourhood_group       neighbourhood  \
# 0          2787           John            Brooklyn          Kensington
# 1          2845       Jennifer           Manhattan             Midtown
# 2          4632      Elisabeth           Manhattan              Harlem
# 3          4869    LisaRoxanne            Brooklyn        Clinton Hill
# 4          7192          Laura           Manhattan         East Harlem
# ...         ...            ...                 ...                 ...
# 48879   8232441        Sabrina            Brooklyn  Bedford-Stuyvesant
# 48880   6570630        Marisol            Brooklyn            Bushwick
# 48881  23492952  Ilgar & Aysel           Manhattan              Harlem
# 48882  30985759            Taz           Manhattan      Hell's Kitchen
# 48883  68119814     Christophe           Manhattan      Hell's Kitchen
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 0      40.64749  -73.97237     Private room    149               1
# 1      40.75362  -73.98377  Entire home/apt    225               1
# 2      40.80902  -73.94190     Private room    150               3
# 3      40.68514  -73.95976  Entire home/apt     89               1
# 4      40.79851  -73.94399  Entire home/apt     80              10
# ...         ...        ...              ...    ...             ...
# 48879  40.67853  -73.94995     Private room     70               2
# 48880  40.70184  -73.93317     Private room     40               4
# 48881  40.81475  -73.94867  Entire home/apt    115              10
# 48882  40.75751  -73.99112      Shared room     55               1
# 48883  40.76404  -73.98933     Private room     90               7
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      9  2018-10-19               0.21
# 1                     45  2019-05-21               0.38
# 2                      0         NaN                NaN
# 3                    270  2019-07-05               4.64
# 4                      9  2018-11-19               0.10
# ...                  ...         ...                ...
# 48879                  0         NaN                NaN
# 48880                  0         NaN                NaN
# 48881                  0         NaN                NaN
# 48882                  0         NaN                NaN
# 48883                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365 Price_category
# 0                                   6               365            70%
# 1                                   2               355           100%
# 2                                   1               365            70%
# 3                                   1               194            50%
# 4                                   1                 0            50%
# ...                               ...               ...            ...
# 48879                               2                 9            50%
# 48880                               2                36            25%
# 48881                               1                27            70%
# 48882                               6                 2            25%
# 48883                               1                23            50%
#
# [48884 rows x 18 columns]

# %%
df.head()
plt.figure(figsize=(12,8))
df1 = df[df['minimum_nights']==1]
df2 = df1.groupby(['room_type','neighbourhood_group'])['price'].mean().sort_values(ascending=True)
df2.plot(kind='bar')
plt.title('Average Price for rooms in neighbourhood group')
plt.ylabel('Average Daily Price')
plt.xlabel('Neighbourhood Group')
plt.show()
print('List of Average Price per night based on the neighbourhood group')
pd.DataFrame(df2).sort_values(by='room_type')
# Out:
# List of Average Price per night based on the neighbourhood group
#                                           price
# room_type       neighbourhood_group
# Entire home/apt Queens               139.036260
#                 Bronx                141.541176
#                 Brooklyn             202.895245
#                 Staten Island        266.205128
#                 Manhattan            291.784595
# Private room    Bronx                 69.025862
#                 Staten Island         71.394366
#                 Queens                72.454958
#                 Brooklyn              81.713284
#                 Manhattan            121.434183
# Shared room     Staten Island         21.000000
#                 Bronx                 46.711111
#                 Brooklyn              60.921212
#                 Queens                68.459459
#                 Manhattan             88.462898

# %%
df1.reset_index(inplace=True)

# %%
#df1.to_dict('records')
# Out:
# [{'index': 0,
#   'id': 2539,
#   'name': 'Clean & quiet apt home by the park',
#   'host_id': 2787,
#   'host_name': 'John',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Kensington',
#   'latitude': 40.64749,
#   'longitude': -73.97237,
#   'room_type': 'Private room',
#   'price': 149,
#   'minimum_nights': 1,
#   'number_of_reviews': 9,
#   'last_review': '2018-10-19',
#   'reviews_per_month': 0.21,
#   'calculated_host_listings_count': 6,
#   'availability_365': 365,
#   'Price_category': '70%'},
#  {'index': 1,
#   'id': 2595,
#   'name': 'Skylit Midtown Castle',
#   'host_id': 2845,
#   'host_name': 'Jennifer',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Midtown',
#   'latitude': 40.75362,
#   'longitude': -73.98377,
#   'room_type': 'Entire home/apt',
#   'price': 225,
#   'minimum_nights': 1,
#   'number_of_reviews': 45,
#   'last_review': '2019-05-21',
#   'reviews_per_month': 0.38,
#   'calculated_host_listings_count': 2,
#   'availability_365': 355,
#   'Price_category': '100%'},
#  {'index': 3,
#   'id': 3831,
#   'name': 'Cozy Entire Floor of Brownstone',
#   'host_id': 4869,
#   'host_name': 'LisaRoxanne',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Clinton Hill',
#   'latitude': 40.68514,
#   'longitude': -73.95976,
#   'room_type': 'Entire home/apt',
#   'price': 89,
#   'minimum_nights': 1,
#   'number_of_reviews': 270,
#   'last_review': '2019-07-05',
#   'reviews_per_month': 4.64,
#   'calculated_host_listings_count': 1,
#   'availability_365': 194,
#   'Price_category': '50%'},
#  {'index': 9,
#   'id': 5238,
#   'name': 'Cute & Cozy Lower East Side 1 bdrm',
#   'host_id': 7549,
#   'host_name': 'Ben',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chinatown',
#   'latitude': 40.71344,
#   'longitude': -73.99037,
#   'room_type': 'Entire home/apt',
#   'price': 150,
#   'minimum_nights': 1,
#   'number_of_reviews': 160,
#   'last_review': '2019-06-09',
#   'reviews_per_month': 1.33,
#   'calculated_host_listings_count': 4,
#   'availability_365': 188,
#   'Price_category': '70%'},
#  {'index': 17,
#   'id': 7322,
#   'name': 'Chelsea Perfect',
#   'host_id': 18946,
#   'host_name': 'Doti',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chelsea',
#   'latitude': 40.74192,
#   'longitude': -73.99501,
#   'room_type': 'Private room',
#   'price': 140,
#   'minimum_nights': 1,
#   'number_of_reviews': 260,
#   'last_review': '2019-07-01',
#   'reviews_per_month': 2.12,
#   'calculated_host_listings_count': 1,
#   'availability_365': 12,
#   'Price_category': '70%'},
#  {'index': 22,
#   'id': 8025,
#   'name': 'CBG Helps Haiti Room#2.5',
#   'host_id': 22486,
#   'host_name': 'Lisel',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Park Slope',
#   'latitude': 40.67989,
#   'longitude': -73.97798,
#   'room_type': 'Private room',
#   'price': 80,
#   'minimum_nights': 1,
#   'number_of_reviews': 39,
#   'last_review': '2019-01-01',
#   'reviews_per_month': 0.37,
#   'calculated_host_listings_count': 6,
#   'availability_365': 364,
#   'Price_category': '50%'},
#  {'index': 25,
#   'id': 8505,
#   'name': 'Sunny Bedroom Across Prospect Park',
#   'host_id': 25326,
#   'host_name': 'Gregory',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Windsor Terrace',
#   'latitude': 40.65599,
#   'longitude': -73.97519,
#   'room_type': 'Private room',
#   'price': 60,
#   'minimum_nights': 1,
#   'number_of_reviews': 19,
#   'last_review': '2019-06-23',
#   'reviews_per_month': 1.37,
#   'calculated_host_listings_count': 2,
#   'availability_365': 85,
#   'Price_category': '25%'},
#  {'index': 34,
#   'id': 10452,
#   'name': 'Large B&B Style rooms',
#   'host_id': 35935,
#   'host_name': 'Angela',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.6831,
#   'longitude': -73.95473,
#   'room_type': 'Private room',
#   'price': 70,
#   'minimum_nights': 1,
#   'number_of_reviews': 74,
#   'last_review': '2019-05-12',
#   'reviews_per_month': 0.66,
#   'calculated_host_listings_count': 2,
#   'availability_365': 269,
#   'Price_category': '50%'},
#  {'index': 38,
#   'id': 11943,
#   'name': 'Country space in the city',
#   'host_id': 45445,
#   'host_name': 'Harriet',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Flatbush',
#   'latitude': 40.63702,
#   'longitude': -73.96327,
#   'room_type': 'Private room',
#   'price': 150,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': nan,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 365,
#   'Price_category': '70%'},
#  {'index': 39,
#   'id': 12048,
#   'name': 'LowerEastSide apt share shortterm 1',
#   'host_id': 7549,
#   'host_name': 'Ben',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Lower East Side',
#   'latitude': 40.71401,
#   'longitude': -73.98917,
#   'room_type': 'Shared room',
#   'price': 40,
#   'minimum_nights': 1,
#   'number_of_reviews': 214,
#   'last_review': '2019-07-05',
#   'reviews_per_month': 1.81,
#   'calculated_host_listings_count': 4,
#   'availability_365': 188,
#   'Price_category': '25%'},
#  {'index': 50,
#   'id': 13808,
#   'name': 'Blue Room for 2 in Brownstone for $1350 monthly',
#   'host_id': 54275,
#   'host_name': 'JT And Tiziana',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.68043,
#   'longitude': -73.93934,
#   'room_type': 'Private room',
#   'price': 80,
#   'minimum_nights': 1,
#   'number_of_reviews': 112,
#   'last_review': '2019-06-16',
#   'reviews_per_month': 1.01,
#   'calculated_host_listings_count': 3,
#   'availability_365': 251,
#   'Price_category': '50%'},
#  {'index': 67,
#   'id': 16580,
#   'name': 'Sunny, Modern room in East Village!',
#   'host_id': 64442,
#   'host_name': 'Reka',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72649,
#   'longitude': -73.97904,
#   'room_type': 'Private room',
#   'price': 80,
#   'minimum_nights': 1,
#   'number_of_reviews': 338,
#   'last_review': '2019-07-01',
#   'reviews_per_month': 4.72,
#   'calculated_host_listings_count': 2,
#   'availability_365': 72,
#   'Price_category': '50%'},
#  {'index': 68,
#   'id': 16595,
#   'name': '*HAVEN LOFT - Entire Floor - Six Windows - Bricks*',
#   'host_id': 64522,
#   'host_name': 'Daniel',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Williamsburg',
#   'latitude': 40.70933,
#   'longitude': -73.96792,
#   'room_type': 'Entire home/apt',
#   'price': 275,
#   'minimum_nights': 1,
#   'number_of_reviews': 148,
#   'last_review': '2019-06-23',
#   'reviews_per_month': 1.4,
#   'calculated_host_listings_count': 1,
#   'availability_365': 362,
#   'Price_category': '100%'},
#  {'index': 69,
#   'id': 16821,
#   'name': 'Large Room in Amazing East Village Apt',
#   'host_id': 4396,
#   'host_name': 'Casey',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72298,
#   'longitude': -73.98474,
#   'room_type': 'Private room',
#   'price': 99,
#   'minimum_nights': 1,
#   'number_of_reviews': 106,
#   'last_review': '2019-06-21',
#   'reviews_per_month': 1.26,
#   'calculated_host_listings_count': 2,
#   'availability_365': 336,
#   'Price_category': '50%'},
#  {'index': 76,
#   'id': 18152,
#   'name': 'Manhattan Room',
#   'host_id': 69942,
#   'host_name': 'Victoria',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.76865,
#   'longitude': -73.95058,
#   'room_type': 'Private room',
#   'price': 200,
#   'minimum_nights': 1,
#   'number_of_reviews': 142,
#   'last_review': '2019-07-06',
#   'reviews_per_month': 1.5,
#   'calculated_host_listings_count': 1,
#   'availability_365': 322,
#   'Price_category': '100%'},
#  {'index': 85,
#   'id': 19601,
#   'name': 'perfect for a family or small group',
#   'host_id': 74303,
#   'host_name': 'Maggie',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Brooklyn Heights',
#   'latitude': 40.69723,
#   'longitude': -73.99268,
#   'room_type': 'Entire home/apt',
#   'price': 800,
#   'minimum_nights': 1,
#   'number_of_reviews': 25,
#   'last_review': '2016-08-04',
#   'reviews_per_month': 0.24,
#   'calculated_host_listings_count': 1,
#   'availability_365': 7,
#   'Price_category': '100%'},
#  {'index': 88,
#   'id': 20300,
#   'name': 'Great Location for NYC',
#   'host_id': 76627,
#   'host_name': 'Pas',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72912,
#   'longitude': -73.98057,
#   'room_type': 'Private room',
#   'price': 50,
#   'minimum_nights': 1,
#   'number_of_reviews': 2,
#   'last_review': '2016-02-14',
#   'reviews_per_month': 0.05,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '25%'},
#  {'index': 97,
#   'id': 21644,
#   'name': 'Upper Manhattan, New York',
#   'host_id': 82685,
#   'host_name': 'Elliott',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.82803,
#   'longitude': -73.94731,
#   'room_type': 'Private room',
#   'price': 89,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': '2018-10-09',
#   'reviews_per_month': 0.11,
#   'calculated_host_listings_count': 1,
#   'availability_365': 365,
#   'Price_category': '50%'},
#  {'index': 118,
#   'id': 27385,
#   'name': 'Great Large 1 BR apt  in East Village!',
#   'host_id': 72062,
#   'host_name': 'Bruce',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72555,
#   'longitude': -73.97965,
#   'room_type': 'Entire home/apt',
#   'price': 225,
#   'minimum_nights': 1,
#   'number_of_reviews': 115,
#   'last_review': '2019-06-07',
#   'reviews_per_month': 1.05,
#   'calculated_host_listings_count': 4,
#   'availability_365': 299,
#   'Price_category': '100%'},
#  {'index': 125,
#   'id': 28396,
#   'name': 'Modern Apt with Spectacular Views',
#   'host_id': 6197784,
#   'host_name': 'Jo',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Williamsburg',
#   'latitude': 40.71923,
#   'longitude': -73.96468,
#   'room_type': 'Private room',
#   'price': 90,
#   'minimum_nights': 1,
#   'number_of_reviews': 9,
#   'last_review': '2011-09-18',
#   'reviews_per_month': 0.08,
#   'calculated_host_listings_count': 1,
#   'availability_365': 245,
#   'Price_category': '50%'},
#  {'index': 159,
#   'id': 39267,
#   'name': 'CENTRAL PARK LOFT all for YOU',
#   'host_id': 168417,
#   'host_name': 'Marie',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.77456,
#   'longitude': -73.95323,
#   'room_type': 'Entire home/apt',
#   'price': 99,
#   'minimum_nights': 1,
#   'number_of_reviews': 234,
#   'last_review': '2019-06-08',
#   'reviews_per_month': 2.6,
#   'calculated_host_listings_count': 2,
#   'availability_365': 164,
#   'Price_category': '50%'},
#  {'index': 171,
#   'id': 44096,
#   'name': 'Room with a View',
#   'host_id': 190409,
#   'host_name': 'Waundell',
#   'neighbourhood_group': 'Bronx',
#   'neighbourhood': 'Highbridge',
#   'latitude': 40.83232,
#   'longitude': -73.93184,
#   'room_type': 'Private room',
#   'price': 40,
#   'minimum_nights': 1,
#   'number_of_reviews': 219,
#   'last_review': '2019-07-04',
#   'reviews_per_month': 2.04,
#   'calculated_host_listings_count': 3,
#   'availability_365': 353,
#   'Price_category': '25%'},
#  {'index': 173,
#   'id': 44212,
#   'name': 'West Inn 2 - East Village',
#   'host_id': 72062,
#   'host_name': 'Bruce',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72518,
#   'longitude': -73.98034,
#   'room_type': 'Private room',
#   'price': 125,
#   'minimum_nights': 1,
#   'number_of_reviews': 84,
#   'last_review': '2019-06-23',
#   'reviews_per_month': 0.78,
#   'calculated_host_listings_count': 4,
#   'availability_365': 310,
#   'Price_category': '70%'},
#  {'index': 190,
#   'id': 47926,
#   'name': 'LUX APT IN TIMES SQUARE NEW BUILDING',
#   'host_id': 218404,
#   'host_name': 'Claudia',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.76307,
#   'longitude': -73.99665,
#   'room_type': 'Entire home/apt',
#   'price': 275,
#   'minimum_nights': 1,
#   'number_of_reviews': 41,
#   'last_review': '2019-06-26',
#   'reviews_per_month': 0.38,
#   'calculated_host_listings_count': 1,
#   'availability_365': 299,
#   'Price_category': '100%'},
#  {'index': 194,
#   'id': 51485,
#   'name': 'Lower East Side $57~/night',
#   'host_id': 236655,
#   'host_name': 'Erina',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Lower East Side',
#   'latitude': 40.72319,
#   'longitude': -73.99201,
#   'room_type': 'Private room',
#   'price': 83,
#   'minimum_nights': 1,
#   'number_of_reviews': 285,
#   'last_review': '2019-06-22',
#   'reviews_per_month': 2.69,
#   'calculated_host_listings_count': 1,
#   'availability_365': 7,
#   'Price_category': '50%'},
#  {'index': 195,
#   'id': 51572,
#   'name': 'Prime Location in Manhattan',
#   'host_id': 237329,
#   'host_name': 'Lee',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chelsea',
#   'latitude': 40.74859,
#   'longitude': -73.99671,
#   'room_type': 'Private room',
#   'price': 123,
#   'minimum_nights': 1,
#   'number_of_reviews': 375,
#   'last_review': '2019-06-18',
#   'reviews_per_month': 3.52,
#   'calculated_host_listings_count': 1,
#   'availability_365': 328,
#   'Price_category': '70%'},
#  {'index': 206,
#   'id': 54544,
#   'name': 'City Room - Private Penthouse Apt.',
#   'host_id': 256161,
#   'host_name': 'Wayne',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.81035,
#   'longitude': -73.94598,
#   'room_type': 'Entire home/apt',
#   'price': 121,
#   'minimum_nights': 1,
#   'number_of_reviews': 104,
#   'last_review': '2019-06-22',
#   'reviews_per_month': 1.0,
#   'calculated_host_listings_count': 5,
#   'availability_365': 247,
#   'Price_category': '70%'},
#  {'index': 207,
#   'id': 54626,
#   'name': 'Cozy bedroom by Yankee Stadium',
#   'host_id': 190409,
#   'host_name': 'Waundell',
#   'neighbourhood_group': 'Bronx',
#   'neighbourhood': 'Highbridge',
#   'latitude': 40.83075,
#   'longitude': -73.93058,
#   'room_type': 'Private room',
#   'price': 45,
#   'minimum_nights': 1,
#   'number_of_reviews': 138,
#   'last_review': '2019-06-30',
#   'reviews_per_month': 1.45,
#   'calculated_host_listings_count': 3,
#   'availability_365': 323,
#   'Price_category': '25%'},
#  {'index': 215,
#   'id': 56467,
#   'name': 'Cozy East Village Railroad 1 Bed!',
#   'host_id': 267593,
#   'host_name': 'Leonardo',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72752,
#   'longitude': -73.98432,
#   'room_type': 'Entire home/apt',
#   'price': 130,
#   'minimum_nights': 1,
#   'number_of_reviews': 204,
#   'last_review': '2019-07-01',
#   'reviews_per_month': 2.04,
#   'calculated_host_listings_count': 1,
#   'availability_365': 192,
#   'Price_category': '70%'},
#  {'index': 217,
#   'id': 56859,
#   'name': 'City Room - Private & Comfy Bedroom',
#   'host_id': 256161,
#   'host_name': 'Wayne',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.81219,
#   'longitude': -73.94499,
#   'room_type': 'Private room',
#   'price': 64,
#   'minimum_nights': 1,
#   'number_of_reviews': 192,
#   'last_review': '2019-06-03',
#   'reviews_per_month': 1.84,
#   'calculated_host_listings_count': 5,
#   'availability_365': 245,
#   'Price_category': '25%'},
#  {'index': 225,
#   'id': 58059,
#   'name': 'PRIVATE Room on Historic Sugar Hill',
#   'host_id': 277379,
#   'host_name': 'Agnes',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.8251,
#   'longitude': -73.94287,
#   'room_type': 'Private room',
#   'price': 60,
#   'minimum_nights': 1,
#   'number_of_reviews': 458,
#   'last_review': '2019-07-03',
#   'reviews_per_month': 4.58,
#   'calculated_host_listings_count': 2,
#   'availability_365': 258,
#   'Price_category': '25%'},
#  {'index': 236,
#   'id': 60666,
#   'name': 'City Room - Private Luxury Suite',
#   'host_id': 256161,
#   'host_name': 'Wayne',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.8118,
#   'longitude': -73.94434,
#   'room_type': 'Private room',
#   'price': 92,
#   'minimum_nights': 1,
#   'number_of_reviews': 189,
#   'last_review': '2019-06-11',
#   'reviews_per_month': 1.82,
#   'calculated_host_listings_count': 5,
#   'availability_365': 253,
#   'Price_category': '50%'},
#  {'index': 258,
#   'id': 63546,
#   'name': 'Large and Cozy Private Bedroom',
#   'host_id': 308652,
#   'host_name': 'Antonín',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Kensington',
#   'latitude': 40.64106,
#   'longitude': -73.97426,
#   'room_type': 'Private room',
#   'price': 39,
#   'minimum_nights': 1,
#   'number_of_reviews': 45,
#   'last_review': '2019-05-16',
#   'reviews_per_month': 0.46,
#   'calculated_host_listings_count': 2,
#   'availability_365': 365,
#   'Price_category': '25%'},
#  {'index': 285,
#   'id': 66275,
#   'name': 'Lower East Side Magic Room',
#   'host_id': 314941,
#   'host_name': 'Tony',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Lower East Side',
#   'latitude': 40.71904,
#   'longitude': -73.99392,
#   'room_type': 'Private room',
#   'price': 95,
#   'minimum_nights': 1,
#   'number_of_reviews': 109,
#   'last_review': '2019-06-23',
#   'reviews_per_month': 1.11,
#   'calculated_host_listings_count': 3,
#   'availability_365': 364,
#   'Price_category': '50%'},
#  {'index': 293,
#   'id': 68099,
#   'name': 'Cozy room in Upper West Side',
#   'host_id': 323517,
#   'host_name': 'Deda',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.80082,
#   'longitude': -73.9652,
#   'room_type': 'Private room',
#   'price': 109,
#   'minimum_nights': 1,
#   'number_of_reviews': 104,
#   'last_review': '2019-06-25',
#   'reviews_per_month': 1.05,
#   'calculated_host_listings_count': 2,
#   'availability_365': 364,
#   'Price_category': '70%'},
#  {'index': 308,
#   'id': 71384,
#   'name': 'Gigantic Private Brooklyn Loft!',
#   'host_id': 365153,
#   'host_name': 'Ben',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Greenpoint',
#   'latitude': 40.72898,
#   'longitude': -73.95552,
#   'room_type': 'Entire home/apt',
#   'price': 229,
#   'minimum_nights': 1,
#   'number_of_reviews': 50,
#   'last_review': '2014-05-13',
#   'reviews_per_month': 0.5,
#   'calculated_host_listings_count': 1,
#   'availability_365': 188,
#   'Price_category': '100%'},
#  {'index': 313,
#   'id': 74240,
#   'name': 'French Garden cottage off Bedford',
#   'host_id': 389924,
#   'host_name': 'Patty',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Williamsburg',
#   'latitude': 40.71903,
#   'longitude': -73.9597,
#   'room_type': 'Entire home/apt',
#   'price': 169,
#   'minimum_nights': 1,
#   'number_of_reviews': 68,
#   'last_review': '2019-06-07',
#   'reviews_per_month': 0.67,
#   'calculated_host_listings_count': 2,
#   'availability_365': 215,
#   'Price_category': '70%'},
#  {'index': 341,
#   'id': 84659,
#   'name': 'Large Studio--Heart of East Village',
#   'host_id': 462776,
#   'host_name': 'Kyle',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72843,
#   'longitude': -73.98895,
#   'room_type': 'Entire home/apt',
#   'price': 139,
#   'minimum_nights': 1,
#   'number_of_reviews': 388,
#   'last_review': '2019-06-26',
#   'reviews_per_month': 3.88,
#   'calculated_host_listings_count': 1,
#   'availability_365': 142,
#   'Price_category': '70%'},
#  {'index': 348,
#   'id': 94035,
#   'name': 'Modern, Safe, Clean, Bright Room in Astoria for 2',
#   'host_id': 35375,
#   'host_name': 'Savannah',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Astoria',
#   'latitude': 40.75961,
#   'longitude': -73.91117,
#   'room_type': 'Private room',
#   'price': 80,
#   'minimum_nights': 1,
#   'number_of_reviews': 42,
#   'last_review': '2019-07-06',
#   'reviews_per_month': 1.21,
#   'calculated_host_listings_count': 2,
#   'availability_365': 365,
#   'Price_category': '50%'},
#  {'index': 360,
#   'id': 100184,
#   'name': 'Bienvenue',
#   'host_id': 526653,
#   'host_name': nan,
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Queens Village',
#   'latitude': 40.72413,
#   'longitude': -73.76133,
#   'room_type': 'Private room',
#   'price': 50,
#   'minimum_nights': 1,
#   'number_of_reviews': 43,
#   'last_review': '2019-07-08',
#   'reviews_per_month': 0.45,
#   'calculated_host_listings_count': 1,
#   'availability_365': 88,
#   'Price_category': '25%'},
#  {'index': 375,
#   'id': 112304,
#   'name': 'Cozy Private Room in West Harlem!',
#   'host_id': 573316,
#   'host_name': 'Kelli',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.8054,
#   'longitude': -73.95189,
#   'room_type': 'Private room',
#   'price': 90,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': '2016-01-02',
#   'reviews_per_month': 0.02,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '50%'},
#  {'index': 381,
#   'id': 114229,
#   'name': 'Lower East Side 2 Bedroom Apt',
#   'host_id': 314941,
#   'host_name': 'Tony',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Lower East Side',
#   'latitude': 40.71895,
#   'longitude': -73.99434,
#   'room_type': 'Entire home/apt',
#   'price': 211,
#   'minimum_nights': 1,
#   'number_of_reviews': 52,
#   'last_review': '2019-06-08',
#   'reviews_per_month': 0.6,
#   'calculated_host_listings_count': 3,
#   'availability_365': 361,
#   'Price_category': '100%'},
#  {'index': 384,
#   'id': 115678,
#   'name': 'Your Stunning Vacation Apartment!',
#   'host_id': 127772,
#   'host_name': 'Will',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.81822,
#   'longitude': -73.94095,
#   'room_type': 'Entire home/apt',
#   'price': 99,
#   'minimum_nights': 1,
#   'number_of_reviews': 320,
#   'last_review': '2019-06-23',
#   'reviews_per_month': 3.23,
#   'calculated_host_listings_count': 1,
#   'availability_365': 220,
#   'Price_category': '50%'},
#  {'index': 397,
#   'id': 125594,
#   'name': 'SUPER BIG AND COZY PRIVATE BEDROOM',
#   'host_id': 308652,
#   'host_name': 'Antonín',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Kensington',
#   'latitude': 40.64302,
#   'longitude': -73.97255,
#   'room_type': 'Private room',
#   'price': 39,
#   'minimum_nights': 1,
#   'number_of_reviews': 82,
#   'last_review': '2019-05-19',
#   'reviews_per_month': 0.94,
#   'calculated_host_listings_count': 2,
#   'availability_365': 365,
#   'Price_category': '25%'},
#  {'index': 399,
#   'id': 126816,
#   'name': 'Gorgeous Upper West Side Apartment',
#   'host_id': 620288,
#   'host_name': 'Eric',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.79918,
#   'longitude': -73.96607,
#   'room_type': 'Private room',
#   'price': 85,
#   'minimum_nights': 1,
#   'number_of_reviews': 3,
#   'last_review': '2014-11-06',
#   'reviews_per_month': 0.03,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '50%'},
#  {'index': 401,
#   'id': 128975,
#   'name': 'City Room - Street View Apt',
#   'host_id': 256161,
#   'host_name': 'Wayne',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.81333,
#   'longitude': -73.94453,
#   'room_type': 'Entire home/apt',
#   'price': 122,
#   'minimum_nights': 1,
#   'number_of_reviews': 116,
#   'last_review': '2019-06-13',
#   'reviews_per_month': 1.18,
#   'calculated_host_listings_count': 5,
#   'availability_365': 271,
#   'Price_category': '70%'},
#  {'index': 418,
#   'id': 141335,
#   'name': "Architect's Brownstone",
#   'host_id': 687361,
#   'host_name': 'Orna',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Park Slope',
#   'latitude': 40.67535,
#   'longitude': -73.97654,
#   'room_type': 'Entire home/apt',
#   'price': 495,
#   'minimum_nights': 1,
#   'number_of_reviews': 35,
#   'last_review': '2018-01-13',
#   'reviews_per_month': 0.41,
#   'calculated_host_listings_count': 1,
#   'availability_365': 355,
#   'Price_category': '100%'},
#  {'index': 423,
#   'id': 144148,
#   'name': '1 Bdrm in 4 Bdrm dupelx/roof deck',
#   'host_id': 299755,
#   'host_name': 'Jonathan',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72217,
#   'longitude': -73.98419,
#   'room_type': 'Private room',
#   'price': 96,
#   'minimum_nights': 1,
#   'number_of_reviews': 34,
#   'last_review': '2016-01-05',
#   'reviews_per_month': 0.58,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '50%'},
#  {'index': 433,
#   'id': 149777,
#   'name': 'Artsy 1 bedroom Apt. 20 min to 42nd Grand Central!',
#   'host_id': 716306,
#   'host_name': 'Dee, Dre & Mama Shelley',
#   'neighbourhood_group': 'Bronx',
#   'neighbourhood': 'Woodlawn',
#   'latitude': 40.89747,
#   'longitude': -73.8639,
#   'room_type': 'Entire home/apt',
#   'price': 77,
#   'minimum_nights': 1,
#   'number_of_reviews': 197,
#   'last_review': '2019-06-23',
#   'reviews_per_month': 2.49,
#   'calculated_host_listings_count': 1,
#   'availability_365': 309,
#   'Price_category': '50%'},
#  {'index': 435,
#   'id': 151199,
#   'name': 'Astoria-Private Home NYC-',
#   'host_id': 722320,
#   'host_name': 'Gladys & Bob',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Astoria',
#   'latitude': 40.75725,
#   'longitude': -73.91098,
#   'room_type': 'Entire home/apt',
#   'price': 129,
#   'minimum_nights': 1,
#   'number_of_reviews': 414,
#   'last_review': '2019-07-03',
#   'reviews_per_month': 4.34,
#   'calculated_host_listings_count': 1,
#   'availability_365': 245,
#   'Price_category': '70%'},
#  {'index': 447,
#   'id': 158061,
#   'name': 'Hancock Town House!-Stuyvesant Mews',
#   'host_id': 758441,
#   'host_name': 'Fred',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.68669,
#   'longitude': -73.91989,
#   'room_type': 'Private room',
#   'price': 165,
#   'minimum_nights': 1,
#   'number_of_reviews': 27,
#   'last_review': '2017-10-08',
#   'reviews_per_month': 0.28,
#   'calculated_host_listings_count': 4,
#   'availability_365': 311,
#   'Price_category': '70%'},
#  {'index': 452,
#   'id': 159749,
#   'name': 'Purple Room for 2/3 in brownstone $1450 per month',
#   'host_id': 54275,
#   'host_name': 'JT And Tiziana',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.67963,
#   'longitude': -73.93908,
#   'room_type': 'Private room',
#   'price': 88,
#   'minimum_nights': 1,
#   'number_of_reviews': 64,
#   'last_review': '2019-07-01',
#   'reviews_per_month': 0.68,
#   'calculated_host_listings_count': 3,
#   'availability_365': 238,
#   'Price_category': '50%'},
#  {'index': 453,
#   'id': 159815,
#   'name': 'Red Room for two in Brownstone for $1355/mo',
#   'host_id': 54275,
#   'host_name': 'JT And Tiziana',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.6798,
#   'longitude': -73.93908,
#   'room_type': 'Private room',
#   'price': 80,
#   'minimum_nights': 1,
#   'number_of_reviews': 39,
#   'last_review': '2019-06-24',
#   'reviews_per_month': 0.41,
#   'calculated_host_listings_count': 3,
#   'availability_365': 218,
#   'Price_category': '50%'},
#  {'index': 476,
#   'id': 167222,
#   'name': 'CBG# 4Tiny room w/ huge window/AC',
#   'host_id': 22486,
#   'host_name': 'Lisel',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Park Slope',
#   'latitude': 40.6788,
#   'longitude': -73.97643,
#   'room_type': 'Private room',
#   'price': 60,
#   'minimum_nights': 1,
#   'number_of_reviews': 20,
#   'last_review': '2018-08-24',
#   'reviews_per_month': 0.21,
#   'calculated_host_listings_count': 6,
#   'availability_365': 258,
#   'Price_category': '25%'},
#  {'index': 504,
#   'id': 179741,
#   'name': 'Spring & Mulberry 2 Bedroom Apartment',
#   'host_id': 314941,
#   'host_name': 'Tony',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Nolita',
#   'latitude': 40.72133,
#   'longitude': -73.99666,
#   'room_type': 'Entire home/apt',
#   'price': 300,
#   'minimum_nights': 1,
#   'number_of_reviews': 6,
#   'last_review': '2019-06-28',
#   'reviews_per_month': 0.06,
#   'calculated_host_listings_count': 3,
#   'availability_365': 115,
#   'Price_category': '100%'},
#  {'index': 515,
#   'id': 187986,
#   'name': 'Comfort at Crossroads of Downtown',
#   'host_id': 904833,
#   'host_name': 'Daniel',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chelsea',
#   'latitude': 40.73862,
#   'longitude': -73.99758,
#   'room_type': 'Entire home/apt',
#   'price': 250,
#   'minimum_nights': 1,
#   'number_of_reviews': 2,
#   'last_review': '2015-08-28',
#   'reviews_per_month': 0.02,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '100%'},
#  {'index': 518,
#   'id': 188674,
#   'name': 'UNION SQUARE/ E. VILL 1BR BEAUTIFUL',
#   'host_id': 909234,
#   'host_name': 'Leslie',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.73217,
#   'longitude': -73.98801,
#   'room_type': 'Entire home/apt',
#   'price': 165,
#   'minimum_nights': 1,
#   'number_of_reviews': 63,
#   'last_review': '2018-01-12',
#   'reviews_per_month': 0.68,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '70%'},
#  {'index': 519,
#   'id': 189135,
#   'name': "Hell's Kitchen Funky 80's Hideaway!",
#   'host_id': 179020,
#   'host_name': 'Michael',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.76311,
#   'longitude': -73.99388,
#   'room_type': 'Private room',
#   'price': 99,
#   'minimum_nights': 1,
#   'number_of_reviews': 89,
#   'last_review': '2019-07-01',
#   'reviews_per_month': 1.0,
#   'calculated_host_listings_count': 1,
#   'availability_365': 353,
#   'Price_category': '50%'},
#  {'index': 533,
#   'id': 195123,
#   'name': 'Cheerful, comfortable room',
#   'host_id': 940724,
#   'host_name': 'Susan',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Washington Heights',
#   'latitude': 40.83403,
#   'longitude': -73.94553,
#   'room_type': 'Private room',
#   'price': 50,
#   'minimum_nights': 1,
#   'number_of_reviews': 225,
#   'last_review': '2019-06-12',
#   'reviews_per_month': 2.35,
#   'calculated_host_listings_count': 1,
#   'availability_365': 343,
#   'Price_category': '25%'},
#  {'index': 534,
#   'id': 195233,
#   'name': 'Hospitality on Propsect Pk-12 yrs Hosting Legally!',
#   'host_id': 949221,
#   'host_name': 'Dennis',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Prospect-Lefferts Gardens',
#   'latitude': 40.65513,
#   'longitude': -73.95641,
#   'room_type': 'Private room',
#   'price': 43,
#   'minimum_nights': 1,
#   'number_of_reviews': 401,
#   'last_review': '2019-07-04',
#   'reviews_per_month': 6.62,
#   'calculated_host_listings_count': 2,
#   'availability_365': 43,
#   'Price_category': '25%'},
#  {'index': 535,
#   'id': 195240,
#   'name': 'Prospect Pk*NYC in 5 stops* Cozy,Clean & Legal!',
#   'host_id': 949221,
#   'host_name': 'Dennis',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Prospect-Lefferts Gardens',
#   'latitude': 40.65589,
#   'longitude': -73.95539,
#   'room_type': 'Private room',
#   'price': 42,
#   'minimum_nights': 1,
#   'number_of_reviews': 72,
#   'last_review': '2019-06-17',
#   'reviews_per_month': 0.84,
#   'calculated_host_listings_count': 2,
#   'availability_365': 96,
#   'Price_category': '25%'},
#  {'index': 536,
#   'id': 195578,
#   'name': 'Loft Style Apt in Williamsburg',
#   'host_id': 304493,
#   'host_name': 'Erika',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Williamsburg',
#   'latitude': 40.70275,
#   'longitude': -73.94501,
#   'room_type': 'Private room',
#   'price': 85,
#   'minimum_nights': 1,
#   'number_of_reviews': 46,
#   'last_review': '2018-12-30',
#   'reviews_per_month': 0.97,
#   'calculated_host_listings_count': 1,
#   'availability_365': 59,
#   'Price_category': '50%'},
#  {'index': 538,
#   'id': 195989,
#   'name': 'Sunny, Large, Park Slope Bedroom',
#   'host_id': 611716,
#   'host_name': 'Elizabeth',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Park Slope',
#   'latitude': 40.67617,
#   'longitude': -73.98136,
#   'room_type': 'Private room',
#   'price': 105,
#   'minimum_nights': 1,
#   'number_of_reviews': 211,
#   'last_review': '2019-06-15',
#   'reviews_per_month': 2.21,
#   'calculated_host_listings_count': 2,
#   'availability_365': 252,
#   'Price_category': '50%'},
#  {'index': 540,
#   'id': 197155,
#   'name': 'Quiet Jr Alcove Near Times Square!',
#   'host_id': 960836,
#   'host_name': 'Vlad',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.76415,
#   'longitude': -73.99067,
#   'room_type': 'Entire home/apt',
#   'price': 149,
#   'minimum_nights': 1,
#   'number_of_reviews': 122,
#   'last_review': '2019-06-23',
#   'reviews_per_month': 1.29,
#   'calculated_host_listings_count': 1,
#   'availability_365': 20,
#   'Price_category': '70%'},
#  {'index': 545,
#   'id': 200645,
#   'name': 'Best Manhattan Studio Deal!   ',
#   'host_id': 933378,
#   'host_name': 'Edo',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.76739,
#   'longitude': -73.9557,
#   'room_type': 'Shared room',
#   'price': 90,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': nan,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '50%'},
#  {'index': 549,
#   'id': 203901,
#   'name': 'Beautiful UES apartment',
#   'host_id': 1000477,
#   'host_name': 'Elizabeth',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.7694,
#   'longitude': -73.9572,
#   'room_type': 'Entire home/apt',
#   'price': 190,
#   'minimum_nights': 1,
#   'number_of_reviews': 8,
#   'last_review': '2016-09-18',
#   'reviews_per_month': 0.08,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '100%'},
#  {'index': 553,
#   'id': 205043,
#   'name': 'Modern Condo in Midtown',
#   'host_id': 1007558,
#   'host_name': 'Welcome To My Place',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Theater District',
#   'latitude': 40.75895,
#   'longitude': -73.9883,
#   'room_type': 'Private room',
#   'price': 150,
#   'minimum_nights': 1,
#   'number_of_reviews': 330,
#   'last_review': '2019-06-20',
#   'reviews_per_month': 7.14,
#   'calculated_host_listings_count': 1,
#   'availability_365': 111,
#   'Price_category': '70%'},
#  {'index': 565,
#   'id': 211974,
#   'name': 'East Village House -- Unique!',
#   'host_id': 272730,
#   'host_name': 'Goldi',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72956,
#   'longitude': -73.97903,
#   'room_type': 'Entire home/apt',
#   'price': 250,
#   'minimum_nights': 1,
#   'number_of_reviews': 60,
#   'last_review': '2019-07-01',
#   'reviews_per_month': 0.65,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '100%'},
#  {'index': 569,
#   'id': 213272,
#   'name': 'CreaTive Live-In Artspace/Birdsnest',
#   'host_id': 293130,
#   'host_name': 'Meli',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bushwick',
#   'latitude': 40.70051,
#   'longitude': -73.92204,
#   'room_type': 'Private room',
#   'price': 40,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': '2019-04-21',
#   'reviews_per_month': 0.37,
#   'calculated_host_listings_count': 1,
#   'availability_365': 5,
#   'Price_category': '25%'},
#  {'index': 577,
#   'id': 219066,
#   'name': 'Wonderful Studio In Brooklyn, NY!!!',
#   'host_id': 447754,
#   'host_name': 'Yana',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bensonhurst',
#   'latitude': 40.61922,
#   'longitude': -73.99399,
#   'room_type': 'Entire home/apt',
#   'price': 110,
#   'minimum_nights': 1,
#   'number_of_reviews': 24,
#   'last_review': '2019-01-19',
#   'reviews_per_month': 0.26,
#   'calculated_host_listings_count': 1,
#   'availability_365': 183,
#   'Price_category': '70%'},
#  {'index': 579,
#   'id': 219793,
#   'name': '✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿',
#   'host_id': 1138692,
#   'host_name': 'Keera (Jena)',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Lower East Side',
#   'latitude': 40.71813,
#   'longitude': -73.98416,
#   'room_type': 'Entire home/apt',
#   'price': 199,
#   'minimum_nights': 1,
#   'number_of_reviews': 29,
#   'last_review': '2015-06-03',
#   'reviews_per_month': 0.31,
#   'calculated_host_listings_count': 2,
#   'availability_365': 162,
#   'Price_category': '100%'},
#  {'index': 580,
#   'id': 219818,
#   'name': '✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿',
#   'host_id': 1138692,
#   'host_name': 'Keera (Jena)',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Lower East Side',
#   'latitude': 40.71892,
#   'longitude': -73.98401,
#   'room_type': 'Entire home/apt',
#   'price': 199,
#   'minimum_nights': 1,
#   'number_of_reviews': 14,
#   'last_review': '2015-07-20',
#   'reviews_per_month': 0.15,
#   'calculated_host_listings_count': 2,
#   'availability_365': 158,
#   'Price_category': '100%'},
#  {'index': 581,
#   'id': 219922,
#   'name': 'Lovely Bdr in Harlem, Manhattan',
#   'host_id': 1139574,
#   'host_name': 'Carmel',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.816,
#   'longitude': -73.95545,
#   'room_type': 'Private room',
#   'price': 100,
#   'minimum_nights': 1,
#   'number_of_reviews': 33,
#   'last_review': '2019-05-25',
#   'reviews_per_month': 0.38,
#   'calculated_host_listings_count': 1,
#   'availability_365': 84,
#   'Price_category': '50%'},
#  {'index': 591,
#   'id': 224004,
#   'name': 'Artsy Loft-like Harlem Apartment',
#   'host_id': 1165231,
#   'host_name': 'Deirdre',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.80486,
#   'longitude': -73.95298,
#   'room_type': 'Private room',
#   'price': 69,
#   'minimum_nights': 1,
#   'number_of_reviews': 59,
#   'last_review': '2018-10-26',
#   'reviews_per_month': 0.63,
#   'calculated_host_listings_count': 2,
#   'availability_365': 86,
#   'Price_category': '25%'},
#  {'index': 597,
#   'id': 225926,
#   'name': 'The Notorious B.N.B. { The Erhart }',
#   'host_id': 1177497,
#   'host_name': 'Jessica',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Clinton Hill',
#   'latitude': 40.68999,
#   'longitude': -73.96711,
#   'room_type': 'Private room',
#   'price': 239,
#   'minimum_nights': 1,
#   'number_of_reviews': 164,
#   'last_review': '2019-07-01',
#   'reviews_per_month': 1.73,
#   'calculated_host_listings_count': 11,
#   'availability_365': 356,
#   'Price_category': '100%'},
#  {'index': 607,
#   'id': 229367,
#   'name': 'COMFY ROOM/COFFEE AND BAGEL/WEEKLY DISCOUNT',
#   'host_id': 1097545,
#   'host_name': 'Carol',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72645,
#   'longitude': -73.98035,
#   'room_type': 'Private room',
#   'price': 89,
#   'minimum_nights': 1,
#   'number_of_reviews': 278,
#   'last_review': '2019-07-03',
#   'reviews_per_month': 2.95,
#   'calculated_host_listings_count': 3,
#   'availability_365': 192,
#   'Price_category': '50%'},
#  {'index': 612,
#   'id': 230956,
#   'name': 'Wonderfully inviting East Village',
#   'host_id': 1207399,
#   'host_name': 'Mark',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72709,
#   'longitude': -73.98274,
#   'room_type': 'Private room',
#   'price': 90,
#   'minimum_nights': 1,
#   'number_of_reviews': 109,
#   'last_review': '2015-10-02',
#   'reviews_per_month': 1.15,
#   'calculated_host_listings_count': 1,
#   'availability_365': 333,
#   'Price_category': '50%'},
#  {'index': 615,
#   'id': 232618,
#   'name': 'Spacious, well furnished, high fl. beautiful views',
#   'host_id': 763420,
#   'host_name': 'Selma',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Harlem',
#   'latitude': 40.79442,
#   'longitude': -73.93433,
#   'room_type': 'Entire home/apt',
#   'price': 145,
#   'minimum_nights': 1,
#   'number_of_reviews': 102,
#   'last_review': '2019-06-18',
#   'reviews_per_month': 1.52,
#   'calculated_host_listings_count': 1,
#   'availability_365': 308,
#   'Price_category': '70%'},
#  {'index': 617,
#   'id': 233638,
#   'name': 'rooms for rent in Queens with piano',
#   'host_id': 1012895,
#   'host_name': 'Melody',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Ridgewood',
#   'latitude': 40.70163,
#   'longitude': -73.90867,
#   'room_type': 'Private room',
#   'price': 55,
#   'minimum_nights': 1,
#   'number_of_reviews': 19,
#   'last_review': '2018-07-31',
#   'reviews_per_month': 0.25,
#   'calculated_host_listings_count': 1,
#   'availability_365': 311,
#   'Price_category': '25%'},
#  {'index': 621,
#   'id': 235552,
#   'name': 'HUGE Sunny Duplex Loft with Garden',
#   'host_id': 1234405,
#   'host_name': 'Bertie',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'South Slope',
#   'latitude': 40.66414,
#   'longitude': -73.98574,
#   'room_type': 'Entire home/apt',
#   'price': 300,
#   'minimum_nights': 1,
#   'number_of_reviews': 40,
#   'last_review': '2019-06-16',
#   'reviews_per_month': 0.44,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '100%'},
#  {'index': 633,
#   'id': 239826,
#   'name': 'Amazing 1 bed, live like a Newyorkr',
#   'host_id': 1257760,
#   'host_name': 'Jay',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Gramercy',
#   'latitude': 40.73685,
#   'longitude': -73.98359,
#   'room_type': 'Entire home/apt',
#   'price': 399,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': nan,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 12,
#   'Price_category': '100%'},
#  {'index': 636,
#   'id': 240800,
#   'name': 'Private Room Near Brooklyn Museum ',
#   'host_id': 1263176,
#   'host_name': 'Joseph',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Prospect Heights',
#   'latitude': 40.67722,
#   'longitude': -73.96542,
#   'room_type': 'Private room',
#   'price': 55,
#   'minimum_nights': 1,
#   'number_of_reviews': 147,
#   'last_review': '2019-06-30',
#   'reviews_per_month': 1.57,
#   'calculated_host_listings_count': 1,
#   'availability_365': 293,
#   'Price_category': '25%'},
#  {'index': 637,
#   'id': 241140,
#   'name': 'The Notorious B.N.B. { The Wallace }',
#   'host_id': 1177497,
#   'host_name': 'Jessica',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Clinton Hill',
#   'latitude': 40.68975,
#   'longitude': -73.96703,
#   'room_type': 'Private room',
#   'price': 438,
#   'minimum_nights': 1,
#   'number_of_reviews': 43,
#   'last_review': '2019-04-14',
#   'reviews_per_month': 0.46,
#   'calculated_host_listings_count': 11,
#   'availability_365': 363,
#   'Price_category': '100%'},
#  {'index': 640,
#   'id': 242532,
#   'name': 'The Notorious B.N.B. { The Swoon }',
#   'host_id': 1177497,
#   'host_name': 'Jessica',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Clinton Hill',
#   'latitude': 40.6893,
#   'longitude': -73.96602,
#   'room_type': 'Private room',
#   'price': 279,
#   'minimum_nights': 1,
#   'number_of_reviews': 120,
#   'last_review': '2019-06-19',
#   'reviews_per_month': 1.28,
#   'calculated_host_listings_count': 11,
#   'availability_365': 362,
#   'Price_category': '100%'},
#  {'index': 641,
#   'id': 242643,
#   'name': 'BIG 1br, SLEEPS 4, dishwashr, TV',
#   'host_id': 1273825,
#   'host_name': 'Lauryn',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Williamsburg',
#   'latitude': 40.70832,
#   'longitude': -73.94157,
#   'room_type': 'Entire home/apt',
#   'price': 137,
#   'minimum_nights': 1,
#   'number_of_reviews': 24,
#   'last_review': '2019-01-01',
#   'reviews_per_month': 0.29,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '70%'},
#  {'index': 649,
#   'id': 246351,
#   'name': 'Sweet Apt, Steps From Gramercy Park',
#   'host_id': 1292250,
#   'host_name': 'Jerry',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Gramercy',
#   'latitude': 40.73834,
#   'longitude': -73.9823,
#   'room_type': 'Entire home/apt',
#   'price': 135,
#   'minimum_nights': 1,
#   'number_of_reviews': 5,
#   'last_review': '2015-08-17',
#   'reviews_per_month': 0.06,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '70%'},
#  {'index': 651,
#   'id': 246938,
#   'name': 'Scandinavian-apt for up to 5. LES',
#   'host_id': 936630,
#   'host_name': 'Jens',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Lower East Side',
#   'latitude': 40.71876,
#   'longitude': -73.98851,
#   'room_type': 'Entire home/apt',
#   'price': 154,
#   'minimum_nights': 1,
#   'number_of_reviews': 238,
#   'last_review': '2019-06-23',
#   'reviews_per_month': 2.59,
#   'calculated_host_listings_count': 1,
#   'availability_365': 246,
#   'Price_category': '70%'},
#  {'index': 656,
#   'id': 249867,
#   'name': 'HANCOCK VERY SMALL ROOM',
#   'host_id': 758441,
#   'host_name': 'Fred',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.68707,
#   'longitude': -73.91918,
#   'room_type': 'Private room',
#   'price': 100,
#   'minimum_nights': 1,
#   'number_of_reviews': 7,
#   'last_review': '2018-10-07',
#   'reviews_per_month': 0.08,
#   'calculated_host_listings_count': 4,
#   'availability_365': 281,
#   'Price_category': '50%'},
#  {'index': 659,
#   'id': 250323,
#   'name': 'SPACIOUS PRIVATE LITTLE ITALY FLAT',
#   'host_id': 1311870,
#   'host_name': 'Christy',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chinatown',
#   'latitude': 40.71582,
#   'longitude': -73.99902,
#   'room_type': 'Entire home/apt',
#   'price': 119,
#   'minimum_nights': 1,
#   'number_of_reviews': 49,
#   'last_review': '2014-12-03',
#   'reviews_per_month': 0.58,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '70%'},
#  {'index': 660,
#   'id': 250536,
#   'name': 'The Lenox in Harlem',
#   'host_id': 1313306,
#   'host_name': 'Yvette',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.81068,
#   'longitude': -73.94288,
#   'room_type': 'Private room',
#   'price': 125,
#   'minimum_nights': 1,
#   'number_of_reviews': 11,
#   'last_review': '2017-09-25',
#   'reviews_per_month': 0.12,
#   'calculated_host_listings_count': 2,
#   'availability_365': 365,
#   'Price_category': '70%'},
#  {'index': 664,
#   'id': 251277,
#   'name': 'Private Bdrm /Bath 1 block Ctrl Prk',
#   'host_id': 1317343,
#   'host_name': 'Carol',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.78558,
#   'longitude': -73.9726,
#   'room_type': 'Private room',
#   'price': 140,
#   'minimum_nights': 1,
#   'number_of_reviews': 176,
#   'last_review': '2019-06-29',
#   'reviews_per_month': 1.89,
#   'calculated_host_listings_count': 1,
#   'availability_365': 300,
#   'Price_category': '70%'},
#  {'index': 671,
#   'id': 253548,
#   'name': 'Well Kept  Private Room around  Brighton  Beach',
#   'host_id': 1331493,
#   'host_name': 'Olia',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Brighton Beach',
#   'latitude': 40.58147,
#   'longitude': -73.96726,
#   'room_type': 'Private room',
#   'price': 69,
#   'minimum_nights': 1,
#   'number_of_reviews': 2,
#   'last_review': '2015-06-25',
#   'reviews_per_month': 0.04,
#   'calculated_host_listings_count': 1,
#   'availability_365': 303,
#   'Price_category': '25%'},
#  {'index': 685,
#   'id': 254409,
#   'name': 'Husband & Wife Art-Filled Apartment',
#   'host_id': 1336542,
#   'host_name': 'Stephanie',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Clinton Hill',
#   'latitude': 40.68197,
#   'longitude': -73.96549,
#   'room_type': 'Entire home/apt',
#   'price': 110,
#   'minimum_nights': 1,
#   'number_of_reviews': 2,
#   'last_review': '2014-01-13',
#   'reviews_per_month': 0.03,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '70%'},
#  {'index': 701,
#   'id': 258740,
#   'name': 'Spacious room in beautiful apt! ',
#   'host_id': 1360043,
#   'host_name': 'Adrienne',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.81872,
#   'longitude': -73.94567,
#   'room_type': 'Private room',
#   'price': 58,
#   'minimum_nights': 1,
#   'number_of_reviews': 143,
#   'last_review': '2018-06-30',
#   'reviews_per_month': 2.83,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '25%'},
#  {'index': 718,
#   'id': 263232,
#   'name': 'Cozy&Clean in a great neighborhood',
#   'host_id': 1381171,
#   'host_name': 'Nicole',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.82151,
#   'longitude': -73.94516,
#   'room_type': 'Entire home/apt',
#   'price': 155,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': '2019-01-27',
#   'reviews_per_month': 0.18,
#   'calculated_host_listings_count': 1,
#   'availability_365': 5,
#   'Price_category': '70%'},
#  {'index': 736,
#   'id': 267435,
#   'name': 'Large Sunny Bedroom in QNS NYC',
#   'host_id': 1402454,
#   'host_name': 'Jocelin',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Rego Park',
#   'latitude': 40.73349,
#   'longitude': -73.86009,
#   'room_type': 'Private room',
#   'price': 55,
#   'minimum_nights': 1,
#   'number_of_reviews': 38,
#   'last_review': '2019-07-01',
#   'reviews_per_month': 0.85,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '25%'},
#  {'index': 749,
#   'id': 270680,
#   'name': 'GREAP STUDIO / 4PPL IN MIDTOWN',
#   'host_id': 1315849,
#   'host_name': 'Javier Pedraza',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Williamsburg',
#   'latitude': 40.71073,
#   'longitude': -73.96207,
#   'room_type': 'Private room',
# ...
#   'availability_365': 0,
#   'Price_category': '50%'},
#  {'index': 5440,
#   'id': 3939041,
#   'name': 'Private cozy studio apartment',
#   'host_id': 284199,
#   'host_name': 'Avijit',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Jackson Heights',
#   'latitude': 40.74946,
#   'longitude': -73.89505,
#   'room_type': 'Entire home/apt',
#   'price': 65,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': '2018-02-12',
#   'reviews_per_month': 0.06,
#   'calculated_host_listings_count': 2,
#   'availability_365': 0,
#   'Price_category': '25%'},
#  {'index': 5454,
#   'id': 3946115,
#   'name': 'Large 3 bedroom on Upper West Side',
#   'host_id': 20449763,
#   'host_name': 'Christine',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.80075,
#   'longitude': -73.9677,
#   'room_type': 'Entire home/apt',
#   'price': 450,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': '2016-12-30',
#   'reviews_per_month': 0.03,
#   'calculated_host_listings_count': 1,
#   'availability_365': 121,
#   'Price_category': '100%'},
#  {'index': 5466,
#   'id': 3953314,
#   'name': 'Hamiltons Hideway Lower Level Apt NYC',
#   'host_id': 295128,
#   'host_name': 'Carol Gloria',
#   'neighbourhood_group': 'Bronx',
#   'neighbourhood': 'Clason Point',
#   'latitude': 40.81192,
#   'longitude': -73.85334,
#   'room_type': 'Entire home/apt',
#   'price': 155,
#   'minimum_nights': 1,
#   'number_of_reviews': 19,
#   'last_review': '2019-07-01',
#   'reviews_per_month': 0.35,
#   'calculated_host_listings_count': 7,
#   'availability_365': 332,
#   'Price_category': '70%'},
#  {'index': 5474,
#   'id': 3962586,
#   'name': 'Sunny private room in Gramercy',
#   'host_id': 20536249,
#   'host_name': 'Daphne',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Gramercy',
#   'latitude': 40.73371,
#   'longitude': -73.98576,
#   'room_type': 'Private room',
#   'price': 150,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': '2014-09-14',
#   'reviews_per_month': 0.02,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '70%'},
#  {'index': 5480,
#   'id': 3967945,
#   'name': 'Great Apt steps from Central Park',
#   'host_id': 18481481,
#   'host_name': 'Jeff And Jessica',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Harlem',
#   'latitude': 40.79347,
#   'longitude': -73.95029,
#   'room_type': 'Private room',
#   'price': 90,
#   'minimum_nights': 1,
#   'number_of_reviews': 265,
#   'last_review': '2019-01-06',
#   'reviews_per_month': 4.5,
#   'calculated_host_listings_count': 1,
#   'availability_365': 36,
#   'Price_category': '50%'},
#  {'index': 5482,
#   'id': 3968610,
#   'name': 'Charming apt in Greenwich Village!',
#   'host_id': 20567256,
#   'host_name': 'Marina',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Greenwich Village',
#   'latitude': 40.72818,
#   'longitude': -73.9981,
#   'room_type': 'Entire home/apt',
#   'price': 140,
#   'minimum_nights': 1,
#   'number_of_reviews': 37,
#   'last_review': '2019-06-26',
#   'reviews_per_month': 0.66,
#   'calculated_host_listings_count': 1,
#   'availability_365': 19,
#   'Price_category': '70%'},
#  {'index': 5491,
#   'id': 3971526,
#   'name': 'Sunny, Spacious Room in Brooklyn!',
#   'host_id': 1840581,
#   'host_name': 'Angelica',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Flatbush',
#   'latitude': 40.63762,
#   'longitude': -73.96155,
#   'room_type': 'Private room',
#   'price': 65,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': nan,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '25%'},
#  {'index': 5494,
#   'id': 3971948,
#   'name': 'Charming sunny room in Brooklyn',
#   'host_id': 19808313,
#   'host_name': 'Georgia',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Clinton Hill',
#   'latitude': 40.68316,
#   'longitude': -73.96163,
#   'room_type': 'Entire home/apt',
#   'price': 103,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': nan,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '50%'},
#  {'index': 5502,
#   'id': 3979714,
#   'name': 'Central Park North 1BD',
#   'host_id': 557329,
#   'host_name': 'James',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.8012,
#   'longitude': -73.95424,
#   'room_type': 'Shared room',
#   'price': 75,
#   'minimum_nights': 1,
#   'number_of_reviews': 6,
#   'last_review': '2019-06-13',
#   'reviews_per_month': 0.1,
#   'calculated_host_listings_count': 1,
#   'availability_365': 315,
#   'Price_category': '50%'},
#  {'index': 5503,
#   'id': 3980487,
#   'name': 'Awesome Apartment near Times Sq.',
#   'host_id': 3424328,
#   'host_name': 'Jd',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chelsea',
#   'latitude': 40.73923,
#   'longitude': -73.99827,
#   'room_type': 'Entire home/apt',
#   'price': 500,
#   'minimum_nights': 1,
#   'number_of_reviews': 27,
#   'last_review': '2016-09-17',
#   'reviews_per_month': 0.46,
#   'calculated_host_listings_count': 1,
#   'availability_365': 90,
#   'Price_category': '100%'},
#  {'index': 5505,
#   'id': 3983469,
#   'name': 'Private room near Columbia University',
#   'host_id': 8734291,
#   'host_name': 'Mike',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.80311,
#   'longitude': -73.96648,
#   'room_type': 'Private room',
#   'price': 75,
#   'minimum_nights': 1,
#   'number_of_reviews': 65,
#   'last_review': '2019-07-05',
#   'reviews_per_month': 1.12,
#   'calculated_host_listings_count': 1,
#   'availability_365': 301,
#   'Price_category': '50%'},
#  {'index': 5517,
#   'id': 4000561,
#   'name': 'Large apartment in Manhattan UWS',
#   'host_id': 3325418,
#   'host_name': 'Patricia',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Morningside Heights',
#   'latitude': 40.80395,
#   'longitude': -73.96436,
#   'room_type': 'Entire home/apt',
#   'price': 600,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': nan,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 3,
#   'availability_365': 344,
#   'Price_category': '100%'},
#  {'index': 5518,
#   'id': 4000571,
#   'name': 'Private Suite/Bath in Manhattan NYC',
#   'host_id': 3325418,
#   'host_name': 'Patricia',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Morningside Heights',
#   'latitude': 40.80452,
#   'longitude': -73.96393,
#   'room_type': 'Private room',
#   'price': 200,
#   'minimum_nights': 1,
#   'number_of_reviews': 30,
#   'last_review': '2018-04-30',
#   'reviews_per_month': 0.52,
#   'calculated_host_listings_count': 3,
#   'availability_365': 0,
#   'Price_category': '100%'},
#  {'index': 5522,
#   'id': 4006264,
#   'name': 'Cozy Parkside 1 Bedroom Apartment',
#   'host_id': 942933,
#   'host_name': 'David',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.80489,
#   'longitude': -73.95759,
#   'room_type': 'Entire home/apt',
#   'price': 115,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': '2014-09-25',
#   'reviews_per_month': 0.02,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '70%'},
#  {'index': 5524,
#   'id': 4007770,
#   'name': 'One Bedroom in Heart of Harlem',
#   'host_id': 16949652,
#   'host_name': 'Derrick',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.80655,
#   'longitude': -73.94854,
#   'room_type': 'Entire home/apt',
#   'price': 275,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': nan,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '100%'},
#  {'index': 5528,
#   'id': 4016069,
#   'name': '1C.  Private  Rm in Guesthouse Manhattan',
#   'host_id': 7831209,
#   'host_name': 'Bobi',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Harlem',
#   'latitude': 40.80732,
#   'longitude': -73.93775,
#   'room_type': 'Private room',
#   'price': 55,
#   'minimum_nights': 1,
#   'number_of_reviews': 163,
#   'last_review': '2019-05-14',
#   'reviews_per_month': 2.76,
#   'calculated_host_listings_count': 10,
#   'availability_365': 359,
#   'Price_category': '25%'},
#  {'index': 5529,
#   'id': 4016121,
#   'name': 'Located in the heart of NoLita.',
#   'host_id': 14707270,
#   'host_name': 'Hamish',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Nolita',
#   'latitude': 40.72322,
#   'longitude': -73.99351,
#   'room_type': 'Entire home/apt',
#   'price': 350,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': '2016-01-05',
#   'reviews_per_month': 0.02,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '100%'},
#  {'index': 5533,
#   'id': 4017226,
#   'name': 'Comfortable room in Brooklyn',
#   'host_id': 20830484,
#   'host_name': 'Lorcán',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Gowanus',
#   'latitude': 40.68163,
#   'longitude': -73.98088,
#   'room_type': 'Private room',
#   'price': 60,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': '2014-09-21',
#   'reviews_per_month': 0.02,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '25%'},
#  {'index': 5536,
#   'id': 4025313,
#   'name': 'One Bed Studio at Wall Street',
#   'host_id': 17249397,
#   'host_name': 'Sushant',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Financial District',
#   'latitude': 40.70457,
#   'longitude': -74.00733,
#   'room_type': 'Shared room',
#   'price': 90,
#   'minimum_nights': 1,
#   'number_of_reviews': 8,
#   'last_review': '2015-05-21',
#   'reviews_per_month': 0.14,
#   'calculated_host_listings_count': 2,
#   'availability_365': 0,
#   'Price_category': '50%'},
#  {'index': 5539,
#   'id': 4028670,
#   'name': 'Luxury 1 Bedroom Sublet ',
#   'host_id': 7877288,
#   'host_name': 'James',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Lower East Side',
#   'latitude': 40.72102,
#   'longitude': -73.98622,
#   'room_type': 'Entire home/apt',
#   'price': 120,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': nan,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '70%'},
#  {'index': 5541,
#   'id': 4031463,
#   'name': 'Comfortable Private space with a terrace',
#   'host_id': 20900568,
#   'host_name': 'Mike',
#   'neighbourhood_group': 'Bronx',
#   'neighbourhood': 'Norwood',
#   'latitude': 40.87786,
#   'longitude': -73.87641,
#   'room_type': 'Private room',
#   'price': 50,
#   'minimum_nights': 1,
#   'number_of_reviews': 108,
#   'last_review': '2019-06-28',
#   'reviews_per_month': 1.84,
#   'calculated_host_listings_count': 1,
#   'availability_365': 261,
#   'Price_category': '25%'},
#  {'index': 5550,
#   'id': 4037522,
#   'name': 'Cozy, Safe & Clean room in Astoria',
#   'host_id': 608396,
#   'host_name': 'Kiara',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Astoria',
#   'latitude': 40.76269,
#   'longitude': -73.90816,
#   'room_type': 'Private room',
#   'price': 99,
#   'minimum_nights': 1,
#   'number_of_reviews': 15,
#   'last_review': '2019-02-16',
#   'reviews_per_month': 0.26,
#   'calculated_host_listings_count': 1,
#   'availability_365': 322,
#   'Price_category': '50%'},
#  {'index': 5557,
#   'id': 4041351,
#   'name': 'Private Room In A Comfy 3BR Apt',
#   'host_id': 2034343,
#   'host_name': 'David',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Crown Heights',
#   'latitude': 40.67152,
#   'longitude': -73.92687,
#   'room_type': 'Private room',
#   'price': 80,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': nan,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '50%'},
#  {'index': 5561,
#   'id': 4046281,
#   'name': 'Spacious and Sunny Private Bedroom!',
#   'host_id': 20979850,
#   'host_name': 'David',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72087,
#   'longitude': -73.97952,
#   'room_type': 'Private room',
#   'price': 119,
#   'minimum_nights': 1,
#   'number_of_reviews': 49,
#   'last_review': '2019-06-19',
#   'reviews_per_month': 1.4,
#   'calculated_host_listings_count': 1,
#   'availability_365': 84,
#   'Price_category': '70%'},
#  {'index': 5566,
#   'id': 4047932,
#   'name': 'Central Park Housing',
#   'host_id': 20989479,
#   'host_name': 'Arnab',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.77222,
#   'longitude': -73.98923,
#   'room_type': 'Shared room',
#   'price': 85,
#   'minimum_nights': 1,
#   'number_of_reviews': 33,
#   'last_review': '2015-12-28',
#   'reviews_per_month': 0.56,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '50%'},
#  {'index': 5568,
#   'id': 4050254,
#   'name': 'Mid-Century Modern En-Suite in Brownstone!',
#   'host_id': 9492212,
#   'host_name': 'Emily And Joel',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Park Slope',
#   'latitude': 40.66898,
#   'longitude': -73.97831,
#   'room_type': 'Private room',
#   'price': 169,
#   'minimum_nights': 1,
#   'number_of_reviews': 151,
#   'last_review': '2019-01-19',
#   'reviews_per_month': 2.58,
#   'calculated_host_listings_count': 4,
#   'availability_365': 0,
#   'Price_category': '70%'},
#  {'index': 5580,
#   'id': 4053987,
#   'name': 'Small Private Room for 1 person',
#   'host_id': 1960128,
#   'host_name': 'Luana',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Ozone Park',
#   'latitude': 40.6844,
#   'longitude': -73.8472,
#   'room_type': 'Private room',
#   'price': 58,
#   'minimum_nights': 1,
#   'number_of_reviews': 2,
#   'last_review': '2015-08-16',
#   'reviews_per_month': 0.04,
#   'calculated_host_listings_count': 2,
#   'availability_365': 364,
#   'Price_category': '25%'},
#  {'index': 5583,
#   'id': 4055732,
#   'name': 'Stay in Clinton Hill sprout house!',
#   'host_id': 12368114,
#   'host_name': 'Rachelle',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Clinton Hill',
#   'latitude': 40.68454,
#   'longitude': -73.96382,
#   'room_type': 'Private room',
#   'price': 40,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': '2015-06-07',
#   'reviews_per_month': 0.02,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'Price_category': '25%'},
#  {'index': 5584,
#   'id': 4057361,
#   'name': 'Large, Bright, Studio-Style Bedroom',
#   'host_id': 2075509,
#   'host_name': 'Melissa',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Long Island City',
#   'latitude': 40.75977,
#   'longitude': -73.92904,
#   'room_type': 'Private room',
#   'price': 76,
#   'minimum_nights': 1,
#   'number_of_reviews': 14,
#   'last_review': '2019-04-11',
#   'reviews_per_month': 0.41,
#   'calculated_host_listings_count': 1,
#   'availability_365': 225,
#   'Price_category': '50%'},
#  {'index': 5585,
#   'id': 4058701,
#   'name': 'Spare bedroom for rent in UWS-NYC',
#   'host_id': 20484008,
#   'host_name': 'Mike',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.79408,
#   'longitude': -73.9757,
#   'room_type': 'Private room',
#   'price': 170,
#   'minimum_nights': 1,
#   'number_of_reviews': 3,
#   'last_review': '2015-11-10',
#   'reviews_per_month': 0.05,
#   'calculated_host_listings_count': 2,
#   'availability_365': 0,
#   'Price_category': '70%'},
#  {'index': 5586,
#   'id': 4058949,
#   'name': '3C. Private Rm in Guesthouse Manhattan',
#   'host_id': 7831209,
#   'host_name': 'Bobi',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Harlem',
#   'latitude': 40.80617,
#   'longitude': -73.93868,
#   'room_type': 'Private room',
#   'price': 45,
#   'minimum_nights': 1,
#   'number_of_reviews': 151,
#   'last_review': '2019-05-09',
#   'reviews_per_month': 2.59,
#   'calculated_host_listings_count': 10,
#   'availability_365': 357,
#   'Price_category': '25%'},
#  {'index': 5590,
#   'id': 4060526,
#   'name': 'Private Room A',
#   'host_id': 10384906,
#   'host_name': 'Susan',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Sunset Park',
#   'latitude': 40.64047,
#   'longitude': -74.00842,
#   'room_type': 'Private room',
#   'price': 39,
#   'minimum_nights': 1,
#   'number_of_reviews': 51,
#   'last_review': '2019-06-09',
#   'reviews_per_month': 0.88,
#   'calculated_host_listings_count': 5,
#   'availability_365': 273,
#   'Price_category': '25%'},
#  ...]

# %%
DIC=df1.to_dict()
DIC
# Out:
# {('Shared room', 'Brooklyn'): 50.77372262773723,
#  ('Shared room', 'Staten Island'): 57.44444444444444,
#  ('Shared room', 'Bronx'): 59.8,
#  ('Private room', 'Staten Island'): 62.29255319148936,
#  ('Private room', 'Bronx'): 66.89093701996927,
#  ('Shared room', 'Queens'): 69.02020202020202,
#  ('Private room', 'Queens'): 71.76245551601423,
#  ('Private room', 'Brooklyn'): 76.54542761208769,
#  ('Shared room', 'Manhattan'): 88.97708333333334,
#  ('Private room', 'Manhattan'): 116.7766224004009,
#  ('Entire home/apt', 'Bronx'): 127.5065963060686,
#  ('Entire home/apt', 'Queens'): 147.05057251908397,
#  ('Entire home/apt', 'Staten Island'): 173.8465909090909,
#  ('Entire home/apt', 'Brooklyn'): 178.34620213433772,
#  ('Entire home/apt', 'Manhattan'): 249.25799363539932}

# %%
df['price'] =  df.apply(lambda x: get_price_zeros(x['price'],x['neithbou'],x['room_type'], 0), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/machine-learning-python-template/src/explore.ipynb Cell 25' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://sepeca15-machinelearnin-s2bbb0sedxc.ws-us47.gitpod.io/workspace/machine-learning-python-template/src/explore.ipynb#ch0000031vscode-remote?line=0'>1</a> df['price'] =  df.apply(lambda x: get_price_zeros(x['price'],x['neithbou'],x['room_type'], 0), axis=1)
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/core/apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# /workspace/machine-learning-python-template/src/explore.ipynb Cell 25' in <lambda>(x)
# ----> <a href='vscode-notebook-cell://sepeca15-machinelearnin-s2bbb0sedxc.ws-us47.gitpod.io/workspace/machine-learning-python-template/src/explore.ipynb#ch0000031vscode-remote?line=0'>1</a> df['price'] =  df.apply(lambda x: get_price_zeros(x['price'],x['neithbou'],x['room_type'], 0), axis=1)
#
# NameError: name 'get_price_zeros' is not defined

# %%
df1
# Out:
#        index        id                                               name  \
# 0          0      2539                 Clean & quiet apt home by the park
# 1          1      2595                              Skylit Midtown Castle
# 2          3      3831                    Cozy Entire Floor of Brownstone
# 3          9      5238                 Cute & Cozy Lower East Side 1 bdrm
# 4         17      7322                                    Chelsea Perfect
# ...      ...       ...                                                ...
# 12715  48878  36479723                                      Room for rest
# 12716  48880  36481315  The Raccoon Artist Studio in Williamsburg New ...
# 12717  48887  36483152    Garden Jewel Apartment in Williamsburg New York
# 12718  48889  36484363                                 QUIT PRIVATE HOUSE
# 12719  48893  36485609               43rd St. Time Square-cozy single bed
#
#          host_id    host_name neighbourhood_group   neighbourhood  latitude  \
# 0           2787         John            Brooklyn      Kensington  40.64749
# 1           2845     Jennifer           Manhattan         Midtown  40.75362
# 2           4869  LisaRoxanne            Brooklyn    Clinton Hill  40.68514
# 3           7549          Ben           Manhattan       Chinatown  40.71344
# 4          18946         Doti           Manhattan         Chelsea  40.74192
# ...          ...          ...                 ...             ...       ...
# 12715   41326856  Jeerathinan              Queens        Elmhurst  40.74477
# 12716  208514239        Melki            Brooklyn    Williamsburg  40.71232
# 12717  208514239        Melki            Brooklyn    Williamsburg  40.71232
# 12718  107716952      Michael              Queens         Jamaica  40.69137
# 12719   30985759          Taz           Manhattan  Hell's Kitchen  40.75751
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.95976  Entire home/apt     89               1                270
# 3      -73.99037  Entire home/apt    150               1                160
# 4      -73.99501     Private room    140               1                260
# ...          ...              ...    ...             ...                ...
# 12715  -73.87727     Private room     45               1                  0
# 12716  -73.94220  Entire home/apt    120               1                  0
# 12717  -73.94220  Entire home/apt    170               1                  0
# 12718  -73.80844     Private room     65               1                  0
# 12719  -73.99112      Shared room     55               1                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2      2019-07-05               4.64                               1
# 3      2019-06-09               1.33                               4
# 4      2019-07-01               2.12                               1
# ...           ...                ...                             ...
# 12715         NaN                NaN                               5
# 12716         NaN                NaN                               3
# 12717         NaN                NaN                               3
# 12718         NaN                NaN                               2
# 12719         NaN                NaN                               6
#
#        availability_365 Price_category
# 0                   365            70%
# 1                   355           100%
# 2                   194            50%
# 3                   188            70%
# 4                    12            70%
# ...                 ...            ...
# 12715               172            25%
# 12716               365            70%
# 12717               365            70%
# 12718               163            25%
# 12719                 2            25%
#
# [12720 rows x 18 columns]

# %%
def categoria_precio(precio):
  if precio <= 69:
    return '25%'
  elif precio <= 106:
    return '50%'
  elif precio <= 175:
    return '70%'
  else:
    return '100%'

# %%
df['Price_category'] = df['price'].apply(categoria_precio)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df.longitude,y=df.latitude,hue=df.Price_category)
plt.show()

# %%
fig = go.Figure()
fig.add_trace(go.Box(y=df["price"], name="All"))


fig.update_layout({
    'xaxis': {
        'title_text': "All_df",
    },
    'yaxis': {
        'title_text': "Price",
    },
    })


                
fig.show()

# %%
price_out = df['price'].describe()
print(price_out)

# %%
IQR = price_out['75%']-price_out['25%']
upper = price_out['75%'] + 1.5*IQR
lower = price_out['25%'] - 1.5*IQR
print('The upper & lower bounds for suspected outliers are {} and {}.'.format(upper,lower))

# %%
df[df['price'] > 9000]

# %%
df_corr=df[['price','minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count',  'availability_365']]
plt.figure(figsize=(12, 8))
sns.heatmap(df_corr.corr(), annot=True, cmap='viridis')
plt.show()

# %%
q1_pr = df['price'].quantile(q=0.25)
q2_pr = df['price'].quantile(q=0.5)
q3_pr = df['price'].quantile(q=0.75)

def categoria_precio(precio):
  if precio <= q1_pr:
    return 'min - q1'
  elif precio <= q2_pr:
    return 'q1 - q2'
  elif precio <= q3_pr:
    return 'q2 - q3'
  else:
    return 'q3 - max'

df['Price_category'] = df['price'].apply(categoria_precio).astype('category')
plt.subplots(1, 2, sharex=True, sharey=True, figsize=(16, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(x=df.longitude, y=df.latitude, hue=df.neighbourhood_group, s=3, palette='Paired')
plt.title('Distritos de Nueva York')
plt.subplot(1, 2, 2)
sns.scatterplot(x=df.longitude, y=df.latitude, hue=df.Price_category, hue_order=['min - q1', 'q1 - q2', 'q2 - q3', 'q3 - max'], s=3)
plt.title('Distribución geográfica por rangos de precios')
plt.show()

# %%
df_manhattan = df[df['neighbourhood_group']=='Manhattan']
df_manhattan['Price_category'] = df_manhattan['price'].apply(categoria_precio).astype('category')

plt.figure(figsize=(6, 6))
sns.scatterplot(x=df_manhattan.longitude, y=df_manhattan.latitude, hue=df_manhattan.Price_category, hue_order=['min - q1', 'q1 - q2', 'q2 - q3', 'q3 - max'], s=3, palette='dark')
plt.title('Distribución geográfica por rangos de precios en Manhattan')
plt.show()

# %%
df_outliers = df[(df['price']>=max_pr) | (df['price']<=min_pr)]

df_outliers['Categoria_outliers_precio'] = 'Precios más altos (outliers)'
df_outliers['Categoria_outliers_precio'] = df_outliers['Categoria_outliers_precio'].astype('category')
color = ['k']

plt.figure(figsize=(9,6))
sns.scatterplot(x=df.longitude, y=df.latitude, hue=df.neighbourhood_group, s=5, palette='Paired')
sns.scatterplot(x=df_outliers.longitude, y=df_outliers.latitude, hue=df_outliers.Categoria_outliers_precio, palette=color, s=8, marker='D', legend=False)
plt.title('Ubicación de los alojamientos con precios más altos (atípicos)')
plt.show()

# %%
plt.subplots(1, 2, figsize=(12,4))
plt.subplot(1, 2, 1)
df_outliers['room_type'].value_counts().plot(kind='bar')
plt.title('Cantidad de alojamientos por tipo (solo datos atípicos)')
plt.subplot(1, 2, 2)
df_sin_outliers['room_type'].value_counts().plot(kind='bar')
plt.title('Cantidad de alojamientos por tipo (sin datos atípicos)')
plt.show()

# %%
fig = px.box(df, x='minimum_nights')
fig.show()
q1_mn = df['minimum_nights'].quantile(0.25)
q3_mn = df['minimum_nights'].quantile(0.75)
IQR_mn = q3_mn - q1_mn
max_o_mn = q3_mn + 1.5*IQR_mn
df_outliers_min_nights = df[df['minimum_nights']>max_o_mn]
df_min_nights = df_outliers_min_nights.groupby('host_id').agg({'minimum_nights': np.mean, 'id': pd.Series.nunique})
pd.DataFrame(df_min_nights)

plt.scatter(df_min_nights['id'], df_min_nights['minimum_nights'], s=6)
plt.xlabel('Cantidad de alojamientos del mismo host')
plt.ylabel('Mínimo de noches')
plt.title('Mínimo de noches por cantidad de alojamientos del host')
plt.show()

# %%
df_reviews = df.groupby('host_id').agg({'number_of_reviews': np.sum, 'id': pd.Series.nunique})
pd.DataFrame(df_reviews)

plt.scatter(df_reviews['id'], df_reviews['number_of_reviews'], s=6)
plt.xlabel('Cantidad de alojamientos del mismo host')
plt.ylabel('Total de reviews')
plt.title('Total de reviews por cantidad de alojamientos del host')
plt.show()

# %%
df_reviews_month = df.groupby('host_id').agg({'reviews_per_month': np.sum, 'id': pd.Series.nunique})
pd.DataFrame(df_reviews_month)

plt.scatter(df_reviews_month['id'], df_reviews_month['reviews_per_month'], s=6)
plt.xlabel('Cantidad de alojamientos del mismo host')
plt.ylabel('Total de reviews por mes')
plt.title('Total de reviews por mes por cantidad de alojamientos del host')
plt.show()

# %%
df_no_disponible = df[df['availability_365']==0]
df_no_disponible['Categoria_disponibilidad'] = 'No disponible'
df_no_disponible['Categoria_disponibilidad'] = df_no_disponible['Categoria_disponibilidad'].astype('category')
color = ['k']

plt.figure(figsize=(9,6))
sns.scatterplot(x=df.longitude, y=df.latitude, hue=df.neighbourhood_group, s=5, palette='Paired')
sns.scatterplot(x=df_no_disponible.longitude, y=df_no_disponible.latitude, hue=df_no_disponible.Categoria_disponibilidad, palette=color, s=8, marker='D', legend=False)
plt.title('Ubicación de los alojamientos no disponibles')
plt.show()

# %%
color = ['k']
color2 = ['c']

plt.figure(figsize=(9,6))
sns.scatterplot(x=df_no_disponible.longitude, y=df_no_disponible.latitude, hue=df_no_disponible.Categoria_disponibilidad, palette=color, s=5, legend=True)
sns.scatterplot(x=df_outliers.longitude, y=df_outliers.latitude, hue=df_outliers.Categoria_outliers_precio, palette=color2, s=5, legend=True)
plt.title('Comparación de la ubicación de los alojamientos más caros con la ubicación de los no disponibles')
plt.show()

# %%
df_precio_promedio_no_disponible = df_no_disponible.groupby(['room_type','neighbourhood_group'])['price'].mean().sort_values(ascending=True)
pd.DataFrame(df_precio_promedio_no_disponible).sort_values(by=['room_type', 'price'])

# %%
df_disponible = df[df['availability_365']>0]

df_precio_promedio_disponible = df_disponible.groupby(['room_type','neighbourhood_group'])['price'].mean().sort_values(ascending=True)
pd.DataFrame(df_precio_promedio_disponible).sort_values(by=['room_type', 'price'])

# %%
plt.figure(figsize=(12,6))
df_precio_promedio_disponible.plot(kind='bar', width=-0.4, align='edge')
df_precio_promedio_no_disponible.plot(kind='bar', color='k', width=0.4, align='edge')
plt.legend(['Disponible', 'No disponible'])
plt.title('Precio promedio por tipo de alojamiento y distrito según disponibilidad')
plt.ylabel('Precio promedio')
plt.xlabel('Tipo de alojamiento - Distrito')
plt.show()
